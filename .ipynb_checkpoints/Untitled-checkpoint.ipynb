# %%
df = data.copy()
# Membuat hanyak menampilkan tanggal saja tidak beserta waktu
df['start_duration'] = pd.to_datetime(df['start_duration'].str.replace('T',' ')).dt.date
df['end_duration'] = pd.to_datetime(df['end_duration'].str.replace('T',' ')).dt.date
df['start_registration'] = pd.to_datetime(df['start_registration'].str.replace('T',' ')).dt.date
df['end_registration'] = pd.to_datetime(df['end_registration'].str.replace('T',' ')).dt.date


#Membuat kolom baru untuk kota/kabupaten dan provinsi
df['Kab/Kot'] = ''
df['Provinsi'] = ''
df['Koordinat'] = ''
df.loc[df['location'].isin(['Kota Jakarta Selatan','Mampang Prapatan, Jakarta Selatan, DKI Jakarta',
                       'Jakarta Selatan']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Jakarta Selatan','DKI Jakarta',
                                                                                 '-6.2532216190317715, 106.80619932436043']

df.loc[df['location'].isin(['Kota Jakarta Pusat']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Jakarta Pusat','DKI Jakarta',
                                                                                        '-6.181284430998171, 106.8364620644352']

df.loc[df['location'].isin(['Kota Jakarta Utara']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Jakarta Utara','DKI Jakarta',
                                                                                        '-6.127159255480524, 106.90496558365165']

df.loc[df['location'].isin(['Kota Tangerang','Tangerang, Banten',
                            'Jatake, Tangerang']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Tangerang','Banten',
                                                                                        '-6.190267176145197, 106.64312533958167']

df.loc[df['location'].isin(['Kota Jakarta Barat']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Jakarta Barat','DKI Jakarta',
                                                                                        '-6.163563696610204, 106.74763604860665']

df.loc[df['location'].isin(['Kota Bandung','Kec. Bandung Kulon, Kota Bandung, Jawa Barat',
                            'Kantor LLDIKTI Wilayah IV  Jl. P.H.H. Mustofa No.38 Bandung']),
       ['Kab/Kot','Provinsi','Koordinat']]= ['Kota Bandung','Jawa Barat','-6.894535397518558, 107.6057576302667']

df.loc[df['location'].isin(['Kab. Berau']),['Kab/Kot','Provinsi','Koordinat']]= ['Kab. Berau','Kalimantan Timur',
                                                                                 '2.049427111642366, 117.09199880900077']

df.loc[df['location'].isin(['Kota Yogyakarta','Daerah Istimewa Yogyakarta','Yogyakarta']),
       ['Kab/Kot','Provinsi','Koordinat']]= ['Kota Yogyakarta','DI Yogyakarta','-7.801025305562166, 110.37131651098063']

df.loc[df['location'].isin(['Kab. Sleman']),['Kab/Kot','Provinsi','Koordinat']]= ['Kab. Sleman','DI Yogyakarta',
                                                                                  '-7.741721693052204, 110.39435535728131']

df.loc[df['location'].isin(['Kota Malang']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Malang','Jawa Timur',
                                                                                  '-7.971154616072038, 112.63578707760821']

df.loc[df['location'].isin(['Kab. Tangerang']),['Kab/Kot','Provinsi','Koordinat']]= ['Kab. Tangerang','Banten',
                                                                                    '-6.226699686855993, 106.50082185651176']

df.loc[df['location'].isin(['Kota Jakarta Timur','Cakung, Jakarta Timur']),
       ['Kab/Kot','Provinsi','Koordinat']]= ['Kota Jakarta Timur','DKI Jakarta']

df.loc[df['location'].isin(['Kota Bontang']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Bontang','Kalimantan Timur']

df.loc[df['location'].isin(['Kota Tangerang Selatan',
                            'Kota Tangerang Selatan, Banten']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Tangerang Selatan','Banten']
df.loc[df['location'].isin(['DKI Jakarta','Jakarta','jakarta']),['Kab/Kot','Provinsi','Koordinat']]= ['Tidak Diketahui','DKI Jakarta']

df.loc[df['location'].isin(['Kota Surakarta']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Surakarta','Jawa Tengah']

df.loc[df['location'].isin(['Kab. Boyolali']),['Kab/Kot','Provinsi','Koordinat']]= ['Kab. Boyolali','Jawa Tengah']

df.loc[df['location'].isin(['Kab. Gresik']),['Kab/Kot','Provinsi','Koordinat']]= ['Kab. Gresik','Jawa Timur']

df.loc[df['location'].isin(['Kab. Badung']),['Kab/Kot','Provinsi','Koordinat']]= ['Kab. Badung','Bali']

df.loc[df['location'].isin(['Kab. Kotawaringin Timur']),['Kab/Kot','Provinsi','Koordinat']]= ['Kab. Kotawaringin Timur','Kalimantan Tengah']

df.loc[df['location'].isin(['Kota Depok']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Depok','Jawa Barat']

df.loc[df['location'].isin(['Kab. Bekasi',
                            'Cikarang, Kab. Bekasi, Jawa Barat']),['Kab/Kot','Provinsi','Koordinat']]= ['Kab. Bekasi','Jawa Barat']

df.loc[df['location'].isin(['Kota Semarang']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Semarang','Jawa Tengah']

df.loc[df['location'].isin(['Kota Makassar','Makassar']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Makassar','Sulawesi Selatan']

df.loc[df['location'].isin(['Kota Balikpapan']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Balikpapan','Kalimantan Timur']

df.loc[df['location'].isin(['Kota Surabaya']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Surabaya','Jawa Timur']

df.loc[df['location'].isin(['Kota Madiun']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Madiun','Jawa Timur']

df.loc[df['location'].isin(['Kab. Banyumas']),['Kab/Kot','Provinsi','Koordinat']]= ['Kab. Banyumas','Jawa Tengah']

df.loc[df['location'].isin(['Kota Banda Aceh']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Banda Aceh','Aceh']

df.loc[df['location'].isin(['Sentul, Bogor',
                            'SEAMEO BIOTROP, Jl. Raya Tajur km 6, Bogor 16134, Jawa Barat, Indonesia',
                            'SEAMEO BIOTROP, Jl. Raya Tajur Km. 6 Bogor 16134, Jawa Barat, Indonesia',
                            'SEAMEO BIOTROP, Jl. Raya Tajur Km 6, Bogor 16134, Jawa Barat, Indonesia'])
       ,['Kab/Kot','Provinsi','Koordinat']]= ['Kota Bogor','Jawa Barat']

df.loc[df['location'].isin(['Mandalika']),['Kab/Kot','Provinsi','Koordinat']]= ['Kab. Lombok Tengah','Nusa Tenggara Barat']

df.loc[df['location'].isin(['Jawa Tengah']),['Kab/Kot','Provinsi','Koordinat']]= ['Tidak Diketahui','Jawa Tengah']

df.loc[df['location'].isin(['Kab. Serang']),['Kab/Kot','Provinsi','Koordinat']]= ['Kab. Serang','Banten']

df.loc[df['location'].isin(['Kab. Dairi']),['Kab/Kot','Provinsi','Koordinat']]= ['Kab. Dairi','Sumatera Utara']

df.loc[df['location'].isin(['Kab. Bogor']),['Kab/Kot','Provinsi','Koordinat']]= ['Kab. Bogor','Jawa Barat']

df.loc[df['location'].isin(['Kota Jayapura']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Jayapura','Papua']

df.loc[df['location'].isin(['Kota Bekasi']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Bekasi','Jawa Barat']

df.loc[df['location'].isin(['Kab. Malang']),['Kab/Kot','Provinsi','Koordinat']]= ['Kab. Malang','Jawa Timur']

df.loc[df['location'].isin(['Kota Pekanbaru']),['Kab/Kot','Provinsi','Koordinat']]= ['Kota Pekanbaru','Sumatera Selatan']

df.loc[df['location'].isin(['Sunter, Jakarta Utara & Karawang, Jawa Barat',
                            'Kota Yogyakarta, Kota Tegal, Kota Tangerang, Kota Jakarta Selatan',
                            'Kota Jakarta Selatan, Kota Jakarta Pusat, Kota Bandung',
                            'Kota Balikpapan, Kota Bandung, Jakarta, Jawa Tengah, Yogyakarta',
                            'Kota Jakarta Pusat & 10 Kantor Region Office BSI',
                            'Kota Jakarta Selatan, Kota Bandung',
                            'Indomaret Head Office (Menara PIK) & Indomaret Cabang',
                            'Banten dan Kalimantan Selatan',
                            'Sekolah Mitra Jenjang SMA/SMK/SMP Sederajat di Indonesia',
                            'Kota Jakarta, Serang, Bandung, Semarang,Surabaya, Balikpapan, Palembang, Lampung dan Bali',
                            '42 Lokasi Kabupaten/Kota di Indonesia']),['Kab/Kot','Provinsi','Koordinat']]= ['> 1 Kot/Kab','> 1 Provinsi']

df.loc[df['location'].isin(['Batola dan Banjarmasin Kalimantan Selatan']),
       ['Kab/Kot','Provinsi','Koordinat']]= ['> 1 Kot/Kab','Kalimantan Selatan']



df
